# %% [markdown]
# <a href="https://colab.research.google.com/github/RPGraciotti/BootCampAlura/blob/main/Projeto_final/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install auto-sklearn

# %%
# pip install hyperopt

# %%
# pip install hpsklearn

# %%
pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: PyYAML==5.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.6.4)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.8.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import math
from sklearn.pipeline import make_pipeline
# import autosklearn
from sklearn.datasets import make_classification 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# IncorrectPackageVersionError              Traceback (most recent call last)
# <ipython-input-9-112d036db168> in <module>()
#      10 from sklearn.model_selection import train_test_split
#      11 from sklearn.metrics import accuracy_score
# ---> 12 from autosklearn.classification import AutoSklearnClassifier
#
# /usr/local/lib/python3.7/dist-packages/autosklearn/__init__.py in <module>()
#      11 requirements = requirements.decode('utf-8')
#      12
# ---> 13 dependencies.verify_packages(requirements)
#      14
#      15 if os.name != 'posix':
#
# /usr/local/lib/python3.7/dist-packages/autosklearn/util/dependencies.py in verify_packages(packages)
#      23             operation = match.group('operation1')
#      24             version = match.group('version1')
# ---> 25             _verify_package(name, operation, version)
#      26         else:
#      27             raise ValueError('Unable to read requirement: %s' % package)
#
# /usr/local/lib/python3.7/dist-packages/autosklearn/util/dependencies.py in _verify_package(name, operation, version)
#      60     if not check:
#      61         raise IncorrectPackageVersionError(name, installed_version, operation,
# ---> 62                                            required_version)
#      63
#      64
#
# IncorrectPackageVersionError: found 'scipy' version 1.5.4 but requires scipy version >=1.7.0

# %%
df_clean = pd.read_csv("https://raw.githubusercontent.com/RPGraciotti/BootCampAlura/main/Data/data_clean.csv")
df_clean
# Out:
#      PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...  WINDOW  ICU
# 0                           0            1  ...     0-2    1
# 1                           2            0  ...     0-2    1
# 2                           3            0  ...     0-2    0
# 3                           4            0  ...     0-2    0
# 4                           5            0  ...     0-2    0
# ..                        ...          ...  ...     ...  ...
# 289                       380            0  ...     0-2    1
# 290                       381            1  ...     0-2    0
# 291                       382            0  ...     0-2    1
# 292                       383            0  ...     0-2    0
# 293                       384            0  ...     0-2    0
#
# [294 rows x 61 columns]

# %% [markdown]
# # Auto SkLearn

# %%
x_columns = df_clean.columns
y = df_clean.loc[:,"ICU"]
x = df_clean.drop(["PATIENT_VISIT_IDENTIFIER", "ICU", "WINDOW"], axis = 1)

# %%
x = np.array(x)
y = np.array(y)

# %%
# # Bloco de importações que também vai subir porque vou usar vários
# from sklearn.datasets import make_classification
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from autosklearn.classification import AutoSklearnClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, stratify = y)

# %%
# model = AutoSklearnClassifier(time_left_for_this_task = 5*60, per_run_time_limit = 30)

# %%
# model.fit(x_train, y_train)

# %%
# print(model.sprint_statistics())

# %%
# y_hat = model.predict(x_test)
# acc = accuracy_score(y_test, y_hat)
# print(acc)

# %%
# # example of hyperopt-sklearn for a classification dataset
# from sklearn.datasets import make_classification
# from sklearn.model_selection import train_test_split
# from hpsklearn import HyperoptEstimator
# from hpsklearn import any_classifier
# from hpsklearn import any_preprocessing
# from hyperopt import tpe
# # split into train and test sets
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, stratify = y)
# # define search
# model = HyperoptEstimator(algo=tpe.suggest, max_evals=2, trial_timeout=30)
# # perform the search
# model.fit(x_train, y_train)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  5.89it/s, best loss: 0.42500000000000004]
# 100%|██████████| 1/1 [00:00<00:00,  2.29it/s, best loss: 0.4]

# %%
# # summarize performance
# acc = model.score(x_test, y_test)
# print("Accuracy: %.3f" % acc)
# # summarize the best model
# print(model.best_model())
# Out:
# Accuracy: 0.643
# {'learner': XGBClassifier(colsample_bylevel=0.619142422059725,
#               colsample_bytree=0.5196644641872066, gamma=0.0001390995548960165,
#               learning_rate=0.010001990989981738, max_depth=1,
#               min_child_weight=68, missing=nan, n_estimators=2600,
#               reg_alpha=0.0029112549049494845, reg_lambda=1.7928915929301041,
#               seed=2, subsample=0.889956934268858), 'preprocs': (), 'ex_preprocs': ()}

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 17.71it/s]

# %%
models
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# RidgeClassifierCV                  0.73  ...        0.03
# LGBMClassifier                     0.71  ...        0.06
# LinearDiscriminantAnalysis         0.72  ...        0.04
# NearestCentroid                    0.68  ...        0.03
# RidgeClassifier                    0.71  ...        0.03
# XGBClassifier                      0.70  ...        0.21
# LinearSVC                          0.70  ...        0.06
# NuSVC                              0.69  ...        0.04
# LogisticRegression                 0.69  ...        0.06
# PassiveAggressiveClassifier        0.67  ...        0.02
# SVC                                0.68  ...        0.05
# BaggingClassifier                  0.68  ...        0.06
# BernoulliNB                        0.64  ...        0.02
# SGDClassifier                      0.63  ...        0.03
# DecisionTreeClassifier             0.64  ...        0.02
# RandomForestClassifier             0.67  ...        0.26
# AdaBoostClassifier                 0.62  ...        0.13
# Perceptron                         0.61  ...        0.02
# CalibratedClassifierCV             0.69  ...        0.12
# ExtraTreesClassifier               0.63  ...        0.15
# ExtraTreeClassifier                0.62  ...        0.02
# QuadraticDiscriminantAnalysis      0.64  ...        0.03
# GaussianNB                         0.65  ...        0.02
# KNeighborsClassifier               0.64  ...        0.03
# DummyClassifier                    0.58  ...        0.02
# LabelSpreading                     0.61  ...        0.03
# LabelPropagation                   0.61  ...        0.02
#
# [27 rows x 5 columns]
