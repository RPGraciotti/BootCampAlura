# %% [markdown]
# <a href="https://colab.research.google.com/github/RPGraciotti/BootCampAlura/blob/main/Modulo_1/Aula_2_Primeiras_visualiza%C3%A7%C3%B5es_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://github.com/RPGraciotti/BootCampAlura/raw/main/Modulo_1/A184242189_28_143_208.csv", encoding = "ISO-8859-1",
                 skiprows = 3, sep = ";", skipfooter = 12,
                 thousands = ".", decimal = ",", engine = "python")
df.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
df.info()
pd.options.display.float_format = "{:.2f}".format
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
df.loc[:,["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
use_col = df.mean().index.tolist()
use_col.insert(0, "Unidade da Federação")

# %%
use = df.loc[:,use_col]

# %%
use = use.set_index("Unidade da Federação")
use.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996411254.68
# 12 Acre               10470.07  14001.71  ...  1137341.65  450048530.47
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917247936.05
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876965.09
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705309002.29
#
# [5 rows x 165 columns]

# %%
use.loc[:,"2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
use.loc["12 Acre",]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
use.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
use = use.drop("Total", axis = 1)

# %%
use.T.plot(figsize = (10,6))

# %% [markdown]
# # Desafios:
# ## Reposicionar a legenda:

# %%
import matplotlib.ticker as ticker
ax = use.T.plot(figsize = (10,6))
plt.legend(bbox_to_anchor = (1.1, 1.2))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Série temporal do valor total (em reais) de procedimentos hospitalares por mês de atendimento",
          fontsize = 12)
plt.xlabel("Tempo", fontsize = 15)
plt.ylabel("Valor (R$)", fontsize = 15)
plt.show()

# %% [markdown]
# ## Selecionar 5 estados para plotar:
# ### Vou escolher um estado de cada região, e, como eu suspeito que São Paulo é o estado em que dá o erro nos dados eu não vou utilizá-lo:

# %%
use.index # checar os nomes
estados = use.loc[["13 Amazonas", "29 Bahia", "31 Minas Gerais", "51 Mato Grosso", "43 Rio Grande do Sul"]]

# %%
ax = estados.T.plot(figsize = (10,6))
plt.legend(bbox_to_anchor = (1.3, 1))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Série temporal do valor total (em reais) de procedimentos hospitalares por mês de atendimento de 5 estados brasileiros",
          fontsize = 12)
plt.xlabel("Tempo", fontsize = 15)
plt.ylabel("Valor (R$)", fontsize = 15)
plt.show()
